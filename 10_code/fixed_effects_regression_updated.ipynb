# %% [markdown]
# # Fixed Effect Regression Analysis

# %%
# import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols
from linearmodels import PanelOLS
import warnings
warnings.filterwarnings('ignore')

# %%
# import data
df = pd.read_csv('/Users/jennyshen/Desktop/processed_data_revised.csv')
df.head()
# Out:
#          date  total_activity  citation_issued  citation_rate  day_of_week  \
# 0  2010-12-31             122               13       0.106557            5
# 1  2011-01-01             176               23       0.130682            6
# 2  2011-01-02             214               24       0.112150            7
# 3  2011-01-03             250               32       0.128000            1
# 4  2011-01-04             296               44       0.148649            2
#
#    month  days_end_month  end_of_month  year  days_end_year  end_of_year  \
# 0     12               0          True  2010          181.0        False
# 1      1              30         False  2011          180.0        False
# 2      1              29         False  2011          179.0        False
# 3      1              28         False  2011          178.0        False
# 4      1              27         False  2011          177.0        False
#
#    quarter  days_end_quarter  end_of_quarter    city state
# 0      2.0               0.0            True  denver    co
# 1      3.0              89.0           False  denver    co
# 2      3.0              88.0           False  denver    co
# 3      3.0              87.0           False  denver    co
# 4      3.0              86.0           False  denver    co

# %%
df['date'] = pd.to_datetime(df['date'])

# Define a list of city names
city_names = [('durham', 'nc'), ('madison', 'wi'), ('seattle', 'wa'), ('cincinnati', 'oh')]

# Define a list of end_of_* columns
end_of_columns = ['end_of_month', 'end_of_quarter', 'end_of_year']

for city, state in city_names:
    print("******************************************************************************")
    print(f"\nCity: {city}, State: {state}")

    # Filter the data by city and state
    df_filtered = df[(df['city'] == city) & (df['state'] == state)]

    for end_of_col in end_of_columns:
        print(f"\nFixed Effects Regression for {end_of_col}:")
        
        # Set the index as a MultiIndex with 'date'
        df_filtered[end_of_col] = df_filtered[end_of_col].astype(int)  # Convert True/False to 1/0
        
        # Prepare the dependent and independent variables
        dependent_var = df_filtered['citation_issued']
        independent_vars = sm.add_constant(df_filtered[[end_of_col]])
        independent_vars['year'] = df_filtered['year']
        
        # Create the PanelData structure
        panel_data = df_filtered[['date', 'citation_issued', end_of_col, 'year']]
        panel_data = panel_data.set_index(['date', 'year'])
        
        # Run the regression with TimeEffects
        model = PanelOLS.from_formula(f"citation_issued ~ {end_of_col} + TimeEffects", data=panel_data)
        result = model.fit()
        
        print(result)
# Out:
# ******************************************************************************
#
# City: durham, State: nc
#
# Fixed Effects Regression for end_of_month:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        citation_issued   R-squared:                        0.0032
# Estimator:                   PanelOLS   R-squared (Between):             -0.0228
# No. Observations:                5112   R-squared (Within):               0.0000
# Date:                Tue, Apr 25 2023   R-squared (Overall):             -0.0228
# Time:                        23:04:02   Log-likelihood                -2.208e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      16.349
# Entities:                        5112   P-value                           0.0001
# Avg Obs:                       1.0000   Distribution:                  F(1,5096)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             16.349
#                                         P-value                           0.0001
# Time periods:                      15   Distribution:                  F(1,5096)
# Avg Obs:                       340.80
# Min Obs:                       1.0000
# Max Obs:                       366.00
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# end_of_month    -2.5881     0.6401    -4.0434     0.0001     -3.8430     -1.3333
# ================================================================================
#
# F-test for Poolability: 24.789
# P-value: 0.0000
# Distribution: F(14,5096)
#
# Included effects: Time
#
# Fixed Effects Regression for end_of_quarter:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        citation_issued   R-squared:                        0.0032
# Estimator:                   PanelOLS   R-squared (Between):             -0.0167
# No. Observations:                5112   R-squared (Within):               0.0000
# Date:                Tue, Apr 25 2023   R-squared (Overall):             -0.0167
# Time:                        23:04:02   Log-likelihood                -2.208e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      16.159
# Entities:                        5112   P-value                           0.0001
# Avg Obs:                       1.0000   Distribution:                  F(1,5096)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             16.159
#                                         P-value                           0.0001
# Time periods:                      15   Distribution:                  F(1,5096)
# Avg Obs:                       340.80
# Min Obs:                       1.0000
# Max Obs:                       366.00
#
#                                Parameter Estimates
# ==================================================================================
#                 Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------
# end_of_quarter    -3.1458     0.7826    -4.0198     0.0001     -4.6799     -1.6116
# ==================================================================================
#
# F-test for Poolability: 24.780
# P-value: 0.0000
# Distribution: F(14,5096)
#
# Included effects: Time
#
# Fixed Effects Regression for end_of_year:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        citation_issued   R-squared:                        0.0019
# Estimator:                   PanelOLS   R-squared (Between):              0.0081
# No. Observations:                5112   R-squared (Within):               0.0000
# Date:                Tue, Apr 25 2023   R-squared (Overall):              0.0081
# Time:                        23:04:02   Log-likelihood                -2.208e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      9.5746
# Entities:                        5112   P-value                           0.0020
# Avg Obs:                       1.0000   Distribution:                  F(1,5096)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             9.5746
#                                         P-value                           0.0020
# Time periods:                      15   Distribution:                  F(1,5096)
# Avg Obs:                       340.80
# Min Obs:                       1.0000
# Max Obs:                       366.00
#
#                               Parameter Estimates
# ===============================================================================
#              Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------
# end_of_year     3.8592     1.2472     3.0943     0.0020      1.4141      6.3042
# ===============================================================================
#
# F-test for Poolability: 24.781
# P-value: 0.0000
# Distribution: F(14,5096)
#
# Included effects: Time
# ******************************************************************************
#
# City: madison, State: wi
#
# Fixed Effects Regression for end_of_month:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        citation_issued   R-squared:                        0.0009
# Estimator:                   PanelOLS   R-squared (Between):             -0.0114
# No. Observations:                4551   R-squared (Within):               0.0000
# Date:                Tue, Apr 25 2023   R-squared (Overall):             -0.0114
# Time:                        23:04:02   Log-likelihood                -2.147e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      3.9765
# Entities:                        4551   P-value                           0.0462
# Avg Obs:                       1.0000   Distribution:                  F(1,4536)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             3.9765
#                                         P-value                           0.0462
# Time periods:                      14   Distribution:                  F(1,4536)
# Avg Obs:                       325.07
# Min Obs:                       94.000
# Max Obs:                       366.00
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# end_of_month    -2.0175     1.0117    -1.9941     0.0462     -4.0010     -0.0340
# ================================================================================
#
# F-test for Poolability: 85.137
# P-value: 0.0000
# Distribution: F(13,4536)
#
# Included effects: Time
#
# Fixed Effects Regression for end_of_quarter:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        citation_issued   R-squared:                        0.0044
# Estimator:                   PanelOLS   R-squared (Between):             -0.0184
# No. Observations:                4551   R-squared (Within):               0.0000
# Date:                Tue, Apr 25 2023   R-squared (Overall):             -0.0184
# Time:                        23:04:02   Log-likelihood                -2.146e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      19.985
# Entities:                        4551   P-value                           0.0000
# Avg Obs:                       1.0000   Distribution:                  F(1,4536)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             19.985
#                                         P-value                           0.0000
# Time periods:                      14   Distribution:                  F(1,4536)
# Avg Obs:                       325.07
# Min Obs:                       94.000
# Max Obs:                       366.00
#
#                                Parameter Estimates
# ==================================================================================
#                 Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------
# end_of_quarter    -5.5565     1.2429    -4.4705     0.0000     -7.9932     -3.1197
# ==================================================================================
#
# F-test for Poolability: 85.676
# P-value: 0.0000
# Distribution: F(13,4536)
#
# Included effects: Time
#
# Fixed Effects Regression for end_of_year:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        citation_issued   R-squared:                        0.0022
# Estimator:                   PanelOLS   R-squared (Between):              0.0084
# No. Observations:                4551   R-squared (Within):               0.0000
# Date:                Tue, Apr 25 2023   R-squared (Overall):              0.0084
# Time:                        23:04:02   Log-likelihood                -2.147e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      9.9775
# Entities:                        4551   P-value                           0.0016
# Avg Obs:                       1.0000   Distribution:                  F(1,4536)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             9.9775
#                                         P-value                           0.0016
# Time periods:                      14   Distribution:                  F(1,4536)
# Avg Obs:                       325.07
# Min Obs:                       94.000
# Max Obs:                       366.00
#
#                               Parameter Estimates
# ===============================================================================
#              Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------
# end_of_year     6.2900     1.9913     3.1587     0.0016      2.3860      10.194
# ===============================================================================
#
# F-test for Poolability: 84.822
# P-value: 0.0000
# Distribution: F(13,4536)
#
# Included effects: Time
# ******************************************************************************
#
# City: seattle, State: wa
#
# Fixed Effects Regression for end_of_month:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        citation_issued   R-squared:                     5.301e-06
# Estimator:                   PanelOLS   R-squared (Between):             -0.0006
# No. Observations:                3649   R-squared (Within):               0.0000
# Date:                Tue, Apr 25 2023   R-squared (Overall):             -0.0006
# Time:                        23:04:02   Log-likelihood                 -1.43e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      0.0193
# Entities:                        3649   P-value                           0.8896
# Avg Obs:                       1.0000   Distribution:                  F(1,3638)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             0.0193
#                                         P-value                           0.8896
# Time periods:                      10   Distribution:                  F(1,3638)
# Avg Obs:                       364.90
# Min Obs:                       362.00
# Max Obs:                       366.00
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# end_of_month    -0.0705     0.5074    -0.1389     0.8896     -1.0653      0.9244
# ================================================================================
#
# F-test for Poolability: 708.41
# P-value: 0.0000
# Distribution: F(9,3638)
#
# Included effects: Time
#
# Fixed Effects Regression for end_of_quarter:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        citation_issued   R-squared:                        0.0040
# Estimator:                   PanelOLS   R-squared (Between):             -0.0124
# No. Observations:                3649   R-squared (Within):               0.0000
# Date:                Tue, Apr 25 2023   R-squared (Overall):             -0.0124
# Time:                        23:04:03   Log-likelihood                -1.429e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      14.737
# Entities:                        3649   P-value                           0.0001
# Avg Obs:                       1.0000   Distribution:                  F(1,3638)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             14.737
#                                         P-value                           0.0001
# Time periods:                      10   Distribution:                  F(1,3638)
# Avg Obs:                       364.90
# Min Obs:                       362.00
# Max Obs:                       366.00
#
#                                Parameter Estimates
# ==================================================================================
#                 Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------
# end_of_quarter    -2.3757     0.6189    -3.8388     0.0001     -3.5891     -1.1624
# ==================================================================================
#
# F-test for Poolability: 711.31
# P-value: 0.0000
# Distribution: F(9,3638)
#
# Included effects: Time
#
# Fixed Effects Regression for end_of_year:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        citation_issued   R-squared:                        0.0036
# Estimator:                   PanelOLS   R-squared (Between):             -0.0066
# No. Observations:                3649   R-squared (Within):               0.0000
# Date:                Tue, Apr 25 2023   R-squared (Overall):             -0.0066
# Time:                        23:04:03   Log-likelihood                -1.429e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      12.990
# Entities:                        3649   P-value                           0.0003
# Avg Obs:                       1.0000   Distribution:                  F(1,3638)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             12.990
#                                         P-value                           0.0003
# Time periods:                      10   Distribution:                  F(1,3638)
# Avg Obs:                       364.90
# Min Obs:                       362.00
# Max Obs:                       366.00
#
#                               Parameter Estimates
# ===============================================================================
#              Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------
# end_of_year    -3.5483     0.9845    -3.6042     0.0003     -5.4784     -1.6181
# ===============================================================================
#
# F-test for Poolability: 710.95
# P-value: 0.0000
# Distribution: F(9,3638)
#
# Included effects: Time
# ******************************************************************************
#
# City: cincinnati, State: oh
#
# Fixed Effects Regression for end_of_month:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        citation_issued   R-squared:                        0.0050
# Estimator:                   PanelOLS   R-squared (Between):              0.0216
# No. Observations:                3428   R-squared (Within):               0.0000
# Date:                Tue, Apr 25 2023   R-squared (Overall):              0.0216
# Time:                        23:04:03   Log-likelihood                -1.526e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      17.131
# Entities:                        3428   P-value                           0.0000
# Avg Obs:                       1.0000   Distribution:                  F(1,3417)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             17.131
#                                         P-value                           0.0000
# Time periods:                      10   Distribution:                  F(1,3417)
# Avg Obs:                       342.80
# Min Obs:                       141.00
# Max Obs:                       366.00
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# end_of_month     3.6956     0.8929     4.1390     0.0000      1.9450      5.4462
# ================================================================================
#
# F-test for Poolability: 358.80
# P-value: 0.0000
# Distribution: F(9,3417)
#
# Included effects: Time
#
# Fixed Effects Regression for end_of_quarter:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        citation_issued   R-squared:                        0.0094
# Estimator:                   PanelOLS   R-squared (Between):             -0.0206
# No. Observations:                3428   R-squared (Within):               0.0000
# Date:                Tue, Apr 25 2023   R-squared (Overall):             -0.0206
# Time:                        23:04:03   Log-likelihood                -1.525e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      32.388
# Entities:                        3428   P-value                           0.0000
# Avg Obs:                       1.0000   Distribution:                  F(1,3417)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             32.388
#                                         P-value                           0.0000
# Time periods:                      10   Distribution:                  F(1,3417)
# Avg Obs:                       342.80
# Min Obs:                       141.00
# Max Obs:                       366.00
#
#                                Parameter Estimates
# ==================================================================================
#                 Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------
# end_of_quarter    -6.2315     1.0950    -5.6911     0.0000     -8.3784     -4.0847
# ==================================================================================
#
# F-test for Poolability: 360.88
# P-value: 0.0000
# Distribution: F(9,3417)
#
# Included effects: Time
#
# Fixed Effects Regression for end_of_year:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        citation_issued   R-squared:                     3.637e-05
# Estimator:                   PanelOLS   R-squared (Between):             -0.0008
# No. Observations:                3428   R-squared (Within):               0.0000
# Date:                Tue, Apr 25 2023   R-squared (Overall):             -0.0008
# Time:                        23:04:03   Log-likelihood                -1.527e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      0.1243
# Entities:                        3428   P-value                           0.7245
# Avg Obs:                       1.0000   Distribution:                  F(1,3417)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             0.1243
#                                         P-value                           0.7245
# Time periods:                      10   Distribution:                  F(1,3417)
# Avg Obs:                       342.80
# Min Obs:                       141.00
# Max Obs:                       366.00
#
#                               Parameter Estimates
# ===============================================================================
#              Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------
# end_of_year    -0.6257     1.7750    -0.3525     0.7245     -4.1058      2.8544
# ===============================================================================
#
# F-test for Poolability: 357.12
# P-value: 0.0000
# Distribution: F(9,3417)
#
# Included effects: Time

# %% [markdown]
# # Example of interpretation
# ## Cincinnati

# %%
df['date'] = pd.to_datetime(df['date'])

# Filter the data by city
city_name = 'cincinnati'
df_filtered = df[df['city'] == city_name]

# %% [markdown]
# ## End of Month

# %%
# Set the index as a MultiIndex with 'date'
df_filtered['end_of_month'] = df_filtered['end_of_month'].astype(int)  # Convert True/False to 1/0

# Prepare the dependent and independent variables
dependent_var = df_filtered['citation_issued']
independent_vars = sm.add_constant(df_filtered[['end_of_month']])
independent_vars['year'] = df_filtered['year']

# Create the PanelData structure
panel_data = df_filtered[['date','citation_issued', 'end_of_month', 'year']]
panel_data = panel_data.set_index(['date', 'year'])
panel_data.head()
# Out:
#                  citation_issued  end_of_month
# date       year
# 2009-01-01 2009               70             0
# 2009-01-02 2009              116             0
# 2009-01-03 2009              118             0
# 2009-01-04 2009               56             0
# 2009-01-05 2009              115             0

# %%
# Run the regression with TimeEffects
model = PanelOLS.from_formula("citation_issued ~ end_of_month + TimeEffects", data=panel_data)
result = model.fit()

print(result)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        citation_issued   R-squared:                        0.0050
# Estimator:                   PanelOLS   R-squared (Between):              0.0216
# No. Observations:                3428   R-squared (Within):               0.0000
# Date:                Tue, Apr 25 2023   R-squared (Overall):              0.0216
# Time:                        23:04:03   Log-likelihood                -1.526e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      17.131
# Entities:                        3428   P-value                           0.0000
# Avg Obs:                       1.0000   Distribution:                  F(1,3417)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             17.131
#                                         P-value                           0.0000
# Time periods:                      10   Distribution:                  F(1,3417)
# Avg Obs:                       342.80
# Min Obs:                       141.00
# Max Obs:                       366.00
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# end_of_month     3.6956     0.8929     4.1390     0.0000      1.9450      5.4462
# ================================================================================
#
# F-test for Poolability: 358.80
# P-value: 0.0000
# Distribution: F(9,3417)
#
# Included effects: Time

# %% [markdown]
# The parameter estimate of 3.6956 indicates that, on average, there is an increase of 3.6956 `citation_issued` when it is the end of the month, holding all other variables constant. The p-value of 0.0000 suggests that this effect is statistically significant at 0.05 significance level meaning that there is strong evidence to conclude that there is a true positive relationship between `end_of_month` and `citation_issued`.
#
# In summary, the results suggest that there is a statistically significant increase in the number of citations issued at the end of the month compared to other times, after accounting for time fixed effects.

# %% [markdown]
# ## End of Quarter

# %%
# Set the index as a MultiIndex with 'date'
df_filtered['end_of_quarter'] = df_filtered['end_of_quarter'].astype(int)  # Convert True/False to 1/0

# Prepare the dependent and independent variables
dependent_var = df_filtered['citation_issued']
independent_vars = sm.add_constant(df_filtered[['end_of_quarter']])
independent_vars['year'] = df_filtered['year']

# Create the PanelData structure
panel_data = df_filtered[['date','citation_issued', 'end_of_quarter', 'year']]
panel_data = panel_data.set_index(['date', 'year'])
panel_data.head()
# Out:
#                  citation_issued  end_of_quarter
# date       year
# 2009-01-01 2009               70               0
# 2009-01-02 2009              116               0
# 2009-01-03 2009              118               0
# 2009-01-04 2009               56               0
# 2009-01-05 2009              115               0

# %%
# Run the regression with TimeEffects
model = PanelOLS.from_formula("citation_issued ~ end_of_quarter + TimeEffects", data=panel_data)
result = model.fit()

print(result)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        citation_issued   R-squared:                        0.0094
# Estimator:                   PanelOLS   R-squared (Between):             -0.0206
# No. Observations:                3428   R-squared (Within):               0.0000
# Date:                Tue, Apr 25 2023   R-squared (Overall):             -0.0206
# Time:                        23:04:03   Log-likelihood                -1.525e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      32.388
# Entities:                        3428   P-value                           0.0000
# Avg Obs:                       1.0000   Distribution:                  F(1,3417)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             32.388
#                                         P-value                           0.0000
# Time periods:                      10   Distribution:                  F(1,3417)
# Avg Obs:                       342.80
# Min Obs:                       141.00
# Max Obs:                       366.00
#
#                                Parameter Estimates
# ==================================================================================
#                 Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------
# end_of_quarter    -6.2315     1.0950    -5.6911     0.0000     -8.3784     -4.0847
# ==================================================================================
#
# F-test for Poolability: 360.88
# P-value: 0.0000
# Distribution: F(9,3417)
#
# Included effects: Time

# %% [markdown]
# The parameter estimate of -6.2315 indicates that, on average, there is a decrease of 6.2315 `citation_issued` when it is the end of the quarter, holding all other variables constant. The p-value of 0.0000 suggests that this effect is statistically significant at 0.05 significance level meaning that there is strong evidence to conclude that there is a true relationship between `end_of_quarter` and `citation_issued`.
#
# In summary, the results suggest that there is a statistically significant decrease in the number of citations issued at the end of the quarter compared to other times, after accounting for time fixed effects.

# %% [markdown]
# ## End of Year

# %%
# Set the index as a MultiIndex with 'date'
df_filtered['end_of_year'] = df_filtered['end_of_year'].astype(int)  # Convert True/False to 1/0

# Prepare the dependent and independent variables
dependent_var = df_filtered['citation_issued']
independent_vars = sm.add_constant(df_filtered[['end_of_year']])
independent_vars['year'] = df_filtered['year']

# Create the PanelData structure
panel_data = df_filtered[['date','citation_issued', 'end_of_year', 'year']]
panel_data = panel_data.set_index(['date', 'year'])
panel_data.head()
# Out:
#                  citation_issued  end_of_year
# date       year
# 2009-01-01 2009               70            0
# 2009-01-02 2009              116            0
# 2009-01-03 2009              118            0
# 2009-01-04 2009               56            0
# 2009-01-05 2009              115            0

# %%
# Run the regression with TimeEffects
model = PanelOLS.from_formula("citation_issued ~ end_of_year + TimeEffects", data=panel_data)
result = model.fit()

print(result)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        citation_issued   R-squared:                     3.637e-05
# Estimator:                   PanelOLS   R-squared (Between):             -0.0008
# No. Observations:                3428   R-squared (Within):               0.0000
# Date:                Tue, Apr 25 2023   R-squared (Overall):             -0.0008
# Time:                        23:04:03   Log-likelihood                -1.527e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      0.1243
# Entities:                        3428   P-value                           0.7245
# Avg Obs:                       1.0000   Distribution:                  F(1,3417)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             0.1243
#                                         P-value                           0.7245
# Time periods:                      10   Distribution:                  F(1,3417)
# Avg Obs:                       342.80
# Min Obs:                       141.00
# Max Obs:                       366.00
#
#                               Parameter Estimates
# ===============================================================================
#              Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------
# end_of_year    -0.6257     1.7750    -0.3525     0.7245     -4.1058      2.8544
# ===============================================================================
#
# F-test for Poolability: 357.12
# P-value: 0.0000
# Distribution: F(9,3417)
#
# Included effects: Time

# %% [markdown]
# The parameter estimate of -0.6257 indicates that, on average, there is a decrease of 0.6257 `citation_issued` when it is the end of the year, holding all other variables constant. The p-value of 0.7245 suggests that this effect is not statistically significant at 0.05 significance level meaning that there is insuficcient evidence to conclude that there is a true positive relationship between `end_of_year` and `citation_issued`.
